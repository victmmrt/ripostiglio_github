# %%
import pandas as pd
import numpy as np

# %%
pd.read_excel ("ilc_peps13.xls")
# Out:
#     People at risk of poverty or social exclusion by degree of urbanisation [ilc_peps13]  \
# 0                                                  NaN
# 1                                          Last update
# 2                                         Extracted on
# 3                                       Source of data
# 4                                                  NaN
# 5                                                 UNIT
# 6                                              DEG_URB
# 7                                                  NaN
# 8                                             GEO/TIME
# 9    European Union (EU6-1972, EU9-1980, EU10-1985,...
# 10                European Union (current composition)
# 11    European Union (before the accession of Croatia)
# 12   Euro area (EA11-2000, EA12-2006, EA13-2007, EA...
# 13                            Euro area (19 countries)
# 14                            Euro area (18 countries)
# ...

# %%
dati = pd.read_excel ("ilc_peps13.xls")

# %%
pd.options.display.max_rows = 999

# %%
dati
# Out:
#     People at risk of poverty or social exclusion by degree of urbanisation [ilc_peps13]  \
# 0                                                  NaN
# 1                                          Last update
# 2                                         Extracted on
# 3                                       Source of data
# 4                                                  NaN
# 5                                                 UNIT
# 6                                              DEG_URB
# 7                                                  NaN
# 8                                             GEO/TIME
# 9    European Union (EU6-1972, EU9-1980, EU10-1985,...
# 10                European Union (current composition)
# 11    European Union (before the accession of Croatia)
# 12   Euro area (EA11-2000, EA12-2006, EA13-2007, EA...
# 13                            Euro area (19 countries)
# 14                            Euro area (18 countries)
# ...

# %%
dati.iloc[150:189,:]
# Out:
#     People at risk of poverty or social exclusion by degree of urbanisation [ilc_peps13]  \
# 150  European Union (EU6-1972, EU9-1980, EU10-1985,...
# 151               European Union (current composition)
# 152   European Union (before the accession of Croatia)
# 153  Euro area (EA11-2000, EA12-2006, EA13-2007, EA...
# 154                           Euro area (19 countries)
# 155                           Euro area (18 countries)
# 156                                            Belgium
# 157                                           Bulgaria
# 158                                     Czech Republic
# 159                                            Denmark
# 160   Germany (until 1990 former territory of the FRG)
# 161                                            Estonia
# 162                                            Ireland
# 163                                             Greece
# 164                                              Spain
# ...

# %%
percentage_cities = dati.iloc[150:189,:]

# %%
percentage_cities
# Out:
#     People at risk of poverty or social exclusion by degree of urbanisation [ilc_peps13]  \
# 150  European Union (EU6-1972, EU9-1980, EU10-1985,...
# 151               European Union (current composition)
# 152   European Union (before the accession of Croatia)
# 153  Euro area (EA11-2000, EA12-2006, EA13-2007, EA...
# 154                           Euro area (19 countries)
# 155                           Euro area (18 countries)
# 156                                            Belgium
# 157                                           Bulgaria
# 158                                     Czech Republic
# 159                                            Denmark
# 160   Germany (until 1990 former territory of the FRG)
# 161                                            Estonia
# 162                                            Ireland
# 163                                             Greece
# 164                                              Spain
# ...

# %%
dati.iloc[197:236,:]
# Out:
#     People at risk of poverty or social exclusion by degree of urbanisation [ilc_peps13]  \
# 197  European Union (EU6-1972, EU9-1980, EU10-1985,...
# 198               European Union (current composition)
# 199   European Union (before the accession of Croatia)
# 200  Euro area (EA11-2000, EA12-2006, EA13-2007, EA...
# 201                           Euro area (19 countries)
# 202                           Euro area (18 countries)
# 203                                            Belgium
# 204                                           Bulgaria
# 205                                     Czech Republic
# 206                                            Denmark
# 207   Germany (until 1990 former territory of the FRG)
# 208                                            Estonia
# 209                                            Ireland
# 210                                             Greece
# 211                                              Spain
# ...

# %%
percentage_cities.columns = dati.iloc[149].values
percentage_cities
# Out:
#                                               GEO/TIME  2008  2009  2010  \
# 150  European Union (EU6-1972, EU9-1980, EU10-1985,...     :     :     :
# 151               European Union (current composition)     :     :  22.7
# 152   European Union (before the accession of Croatia)  22.6  22.1  22.7
# 153  Euro area (EA11-2000, EA12-2006, EA13-2007, EA...     :     :     :
# 154                           Euro area (19 countries)  21.6  21.3  21.9
# 155                           Euro area (18 countries)  21.6  21.3  21.8
# 156                                            Belgium  23.7  22.6  24.5
# 157                                           Bulgaria  36.4  35.8  38.1
# 158                                     Czech Republic  15.3    13  12.5
# 159                                            Denmark  20.2  20.3  21.8
# 160   Germany (until 1990 former territory of the FRG)  21.3  21.9  20.8
# 161                                            Estonia  17.9  19.9  18.2
# ...

# %%
percentage_cities_pulito =  percentage_cities.applymap(lambda cella: pulisci(cella))
percentage_cities_pulito
# Out:
#                                               GEO/TIME  2008  2009  2010  \
# 150  European Union (EU6-1972, EU9-1980, EU10-1985,...   NaN   NaN   NaN
# 151               European Union (current composition)   NaN   NaN  22.7
# 152   European Union (before the accession of Croatia)  22.6  22.1  22.7
# 153  Euro area (EA11-2000, EA12-2006, EA13-2007, EA...   NaN   NaN   NaN
# 154                           Euro area (19 countries)  21.6  21.3  21.9
# 155                           Euro area (18 countries)  21.6  21.3  21.8
# 156                                            Belgium  23.7  22.6  24.5
# 157                                           Bulgaria  36.4  35.8  38.1
# 158                                     Czech Republic  15.3  13.0  12.5
# 159                                            Denmark  20.2  20.3  21.8
# 160   Germany (until 1990 former territory of the FRG)  21.3  21.9  20.8
# 161                                            Estonia  17.9  19.9  18.2
# ...

# %%
percentage_towns_and_suburbs = dati.iloc[197:236,:]

# %%
percentage_towns_and_suburbs.columns = dati.iloc[196].values
percentage_towns_and_suburbs
# Out:
#                                               GEO/TIME  2008  2009  2010  \
# 197  European Union (EU6-1972, EU9-1980, EU10-1985,...     :     :     :
# 198               European Union (current composition)     :     :  20.4
# 199   European Union (before the accession of Croatia)  20.4    20  20.3
# 200  Euro area (EA11-2000, EA12-2006, EA13-2007, EA...     :     :     :
# 201                           Euro area (19 countries)  19.8  19.7  20.1
# 202                           Euro area (18 countries)  19.8  19.7  20.1
# 203                                            Belgium  16.8  16.8  16.4
# 204                                           Bulgaria  47.6  54.7    53
# 205                                     Czech Republic  16.9  15.4  14.3
# 206                                            Denmark    13  15.2  15.9
# 207   Germany (until 1990 former territory of the FRG)  17.3  16.1  17.1
# 208                                            Estonia  19.5  14.7  25.9
# ...

# %%
percentage_rural_areas = dati.iloc[244:283,:] 
percentage_rural_areas
# Out:
#     People at risk of poverty or social exclusion by degree of urbanisation [ilc_peps13]  \
# 244  European Union (EU6-1972, EU9-1980, EU10-1985,...
# 245               European Union (current composition)
# 246   European Union (before the accession of Croatia)
# 247  Euro area (EA11-2000, EA12-2006, EA13-2007, EA...
# 248                           Euro area (19 countries)
# 249                           Euro area (18 countries)
# 250                                            Belgium
# 251                                           Bulgaria
# 252                                     Czech Republic
# 253                                            Denmark
# 254   Germany (until 1990 former territory of the FRG)
# 255                                            Estonia
# 256                                            Ireland
# 257                                             Greece
# 258                                              Spain
# ...

# %%
percentage_rural_areas.columns = dati.iloc[243].values

# %%
percentage_rural_areas
# Out:
#                                               GEO/TIME  2008  2009  2010  \
# 244  European Union (EU6-1972, EU9-1980, EU10-1985,...     :     :     :
# 245               European Union (current composition)     :     :  29.1
# 246   European Union (before the accession of Croatia)  29.1    29    29
# 247  Euro area (EA11-2000, EA12-2006, EA13-2007, EA...     :     :     :
# 248                           Euro area (19 countries)    25  25.4  25.4
# 249                           Euro area (18 countries)  24.7  25.1  25.1
# 250                                            Belgium  24.5  20.8  19.1
# 251                                           Bulgaria  50.6  53.9  58.5
# 252                                     Czech Republic  14.1  14.1  16.1
# 253                                            Denmark  15.4  17.7  17.7
# 254   Germany (until 1990 former territory of the FRG)  22.6  22.7  22.8
# 255                                            Estonia  25.6  27.3  24.5
# ...

# %%
import numpy as np

def pulisci(cella):
    if cella == ":": 
        return np.nan
    else:
        return cella

# %%
percentage_rural_areas_pulito =  percentage_rural_areas.applymap(lambda cella: pulisci(cella))
percentage_rural_areas_pulito
# Out:
#                                               GEO/TIME  2008  2009  2010  \
# 244  European Union (EU6-1972, EU9-1980, EU10-1985,...   NaN   NaN   NaN
# 245               European Union (current composition)   NaN   NaN  29.1
# 246   European Union (before the accession of Croatia)  29.1  29.0  29.0
# 247  Euro area (EA11-2000, EA12-2006, EA13-2007, EA...   NaN   NaN   NaN
# 248                           Euro area (19 countries)  25.0  25.4  25.4
# 249                           Euro area (18 countries)  24.7  25.1  25.1
# 250                                            Belgium  24.5  20.8  19.1
# 251                                           Bulgaria  50.6  53.9  58.5
# 252                                     Czech Republic  14.1  14.1  16.1
# 253                                            Denmark  15.4  17.7  17.7
# 254   Germany (until 1990 former territory of the FRG)  22.6  22.7  22.8
# 255                                            Estonia  25.6  27.3  24.5
# ...

# %%
percentage_towns_and_suburbs_pulito = percentage_towns_and_suburbs.applymap(lambda cella: pulisci(cella))
percentage_towns_and_suburbs_pulito
# Out:
#                                               GEO/TIME  2008  2009  2010  \
# 197  European Union (EU6-1972, EU9-1980, EU10-1985,...   NaN   NaN   NaN
# 198               European Union (current composition)   NaN   NaN  20.4
# 199   European Union (before the accession of Croatia)  20.4  20.0  20.3
# 200  Euro area (EA11-2000, EA12-2006, EA13-2007, EA...   NaN   NaN   NaN
# 201                           Euro area (19 countries)  19.8  19.7  20.1
# 202                           Euro area (18 countries)  19.8  19.7  20.1
# 203                                            Belgium  16.8  16.8  16.4
# 204                                           Bulgaria  47.6  54.7  53.0
# 205                                     Czech Republic  16.9  15.4  14.3
# 206                                            Denmark  13.0  15.2  15.9
# 207   Germany (until 1990 former territory of the FRG)  17.3  16.1  17.1
# 208                                            Estonia  19.5  14.7  25.9
# ...

# %%
percentage_cities.applymap(lambda cella: pulisci(cella))

# %%
variazione_08_11_rural = percentage_rural_areas_pulito["2011"] - percentage_rural_areas_pulito["2008"]
variazione_08_11_rural
# Out:
# 244     NaN
# 245     NaN
# 246     0.0
# 247     NaN
# 248     0.9
# 249     0.9
# 250    -6.8
# 251     7.1
# 252     2.6
# 253     3.1
# 254    -1.1
# 255    -0.6
# 256     1.4
# 257    -1.3
# 258     4.9
# 259     0.9
# 260     NaN
# 261     2.6
# 262     0.6
# 263     4.9
# 264     2.6
# 265     2.1
# 266     4.7
# 267     NaN
# 268   -13.3
# 269    -0.8
# 270    -3.4
# 271    -0.6
# 272    -5.7
# 273     0.6
# 274    -0.7
# 275    -0.1
# 276     2.0
# 277    -0.1
# 278     0.0
# 279    -0.1
# 280    -4.3
# 281     NaN
# 282     NaN
# dtype: float64

# %%
variazioni_08_11_suburbs = percentage_towns_and_suburbs_pulito["2011"] - percentage_towns_and_suburbs_pulito["2008"]
variazioni_08_11_suburbs
# Out:
# 197     NaN
# 198     NaN
# 199     0.9
# 200     NaN
# 201     1.3
# 202     1.3
# 203    -1.4
# 204     7.1
# 205    -2.0
# 206     2.9
# 207     0.7
# 208     4.2
# 209    10.3
# 210     9.9
# 211     4.9
# 212     0.0
# 213     NaN
# 214     1.9
# 215     4.7
# 216    16.8
# 217     NaN
# 218     3.6
# 219     2.3
# 220     0.1
# 221     0.4
# 222    -2.1
# 223    -5.7
# 224    -3.5
# 225    -2.1
# 226     1.2
# 227     1.9
# 228     1.3
# 229    -0.2
# 230     0.3
# 231     NaN
# 232    -1.8
# 233    -0.8
# 234     NaN
# 235     NaN
# dtype: float64

# %%
variazioni_08_11_cities = percentage_cities_pulito ["2011"] - percentage_cities_pulito["2008"]
variazioni_08_11_cities
# Out:
# 150    NaN
# 151    NaN
# 152    0.7
# 153    NaN
# 154    1.3
# 155    1.3
# 156    1.8
# 157    2.2
# 158   -1.3
# 159   -1.3
# 160   -0.5
# 161    3.0
# 162    6.9
# 163    6.1
# 164    1.1
# 165    1.3
# 166    NaN
# 167    3.3
# 168    0.9
# 169    6.0
# 170    8.0
# 171   -0.1
# 172    1.8
# 173    2.1
# 174    1.4
# 175   -1.6
# 176   -2.3
# 177   -0.6
# 178    0.4
# 179    0.7
# 180   -1.5
# 181    1.0
# 182    2.4
# 183   -0.2
# 184    3.0
# 185   -0.4
# 186    0.0
# 187    NaN
# 188    NaN
# dtype: float64

# %%
variazioni_11_16_cities = percentage_cities_pulito ["2016"] - percentage_cities_pulito["2011"]
variazioni_11_16_cities
# Out:
# 150     NaN
# 151     0.2
# 152     0.3
# 153     NaN
# 154     1.3
# 155     1.3
# 156     3.8
# 157    -7.5
# 158     0.0
# 159     4.4
# 160     2.9
# 161     1.5
# 162    -3.2
# 163     4.2
# 164     3.3
# 165    -2.6
# 166    -4.6
# 167     2.5
# 168     0.2
# 169   -13.4
# 170    -5.7
# 171    -0.9
# 172    -6.9
# 173    -1.9
# 174     3.4
# 175    -1.4
# 176    -5.0
# 177     2.1
# 178    -4.5
# 179     NaN
# 180    -2.8
# 181     0.3
# 182    -0.3
# 183    -0.3
# 184    -2.3
# 185     NaN
# 186     4.2
# 187    -3.8
# 188     NaN
# dtype: float64

# %%
variazioni_11_16_suburbs = percentage_towns_and_suburbs_pulito["2016"] - percentage_towns_and_suburbs_pulito["2011"]
variazioni_11_16_suburbs
# Out:
# 197     NaN
# 198     0.2
# 199     0.3
# 200     NaN
# 201     0.7
# 202     0.7
# 203     1.1
# 204   -15.8
# 205    -0.1
# 206    -2.0
# 207    -0.4
# 208     2.1
# 209    -5.7
# 210     3.4
# 211    -4.3
# 212     4.6
# 213    -4.2
# 214     2.0
# 215     6.9
# 216   -10.0
# 217     NaN
# 218    12.5
# 219    -3.3
# 220    -2.8
# 221    -1.9
# 222     1.6
# 223    -7.3
# 224    -2.7
# 225    -8.0
# 226     NaN
# 227    -3.2
# 228    -1.8
# 229     0.3
# 230    -1.9
# 231     NaN
# 232     NaN
# 233     0.3
# 234   -19.2
# 235     NaN
# dtype: float64

# %%
variazione_11_16_rural = percentage_rural_areas_pulito["2016"] - percentage_rural_areas_pulito["2011"]
variazione_11_16_rural
# Out:
# 244    NaN
# 245   -3.7
# 246   -3.7
# 247    NaN
# 248   -2.7
# 249   -2.7
# 250    2.0
# 251   -3.9
# 252   -5.3
# 253   -5.1
# 254   -4.3
# 255    1.1
# 256   -6.4
# 257    6.4
# 258    2.1
# 259   -3.6
# 260   -4.7
# 261   -0.4
# 262    5.1
# 263   -9.2
# 264   -0.4
# 265    0.6
# 266   -5.0
# 267    NaN
# 268    5.9
# 269   -1.3
# 270   -4.8
# 271    1.6
# 272    3.7
# 273    NaN
# 274   -2.0
# 275   -1.4
# 276   -0.5
# 277   -0.5
# 278   -1.7
# 279    NaN
# 280   -3.0
# 281    NaN
# 282    NaN
# dtype: float64

# %%
percentage_rural_areas_pulito["var16_11"] = percentage_rural_areas_pulito["2016"] - percentage_rural_areas_pulito["2011"]
percentage_rural_areas_pulito["var08_11"] = percentage_rural_areas_pulito["2011"] - percentage_rural_areas_pulito["2008"]

# %%
percentage_rural_areas1 = percentage_rural_areas_pulito.set_index("GEO/TIME")
percentage_rural_areas1
# Out:
#                                                     2008  2009  2010  2011  \
# GEO/TIME
# European Union (EU6-1972, EU9-1980, EU10-1985, ...   NaN   NaN   NaN  29.1
# European Union (current composition)                 NaN   NaN  29.1  29.2
# European Union (before the accession of Croatia)    29.1  29.0  29.0  29.1
# Euro area (EA11-2000, EA12-2006, EA13-2007, EA1...   NaN   NaN   NaN  25.3
# Euro area (19 countries)                            25.0  25.4  25.4  25.9
# Euro area (18 countries)                            24.7  25.1  25.1  25.6
# Belgium                                             24.5  20.8  19.1  17.7
# Bulgaria                                            50.6  53.9  58.5  57.7
# Czech Republic                                      14.1  14.1  16.1  16.7
# Denmark                                             15.4  17.7  17.7  18.5
# Germany (until 1990 former territory of the FRG)    22.6  22.7  22.8  21.5
# ...

# %%
percentage_cities1 = percentage_cities_pulito.set_index("GEO/TIME")
percentage_cities1
# Out:
#                                                     2008  2009  2010  2011  \
# GEO/TIME
# European Union (EU6-1972, EU9-1980, EU10-1985, ...   NaN   NaN   NaN  23.3
# European Union (current composition)                 NaN   NaN  22.7  23.4
# European Union (before the accession of Croatia)    22.6  22.1  22.7  23.3
# Euro area (EA11-2000, EA12-2006, EA13-2007, EA1...   NaN   NaN   NaN  22.8
# Euro area (19 countries)                            21.6  21.3  21.9  22.9
# Euro area (18 countries)                            21.6  21.3  21.8  22.9
# Belgium                                             23.7  22.6  24.5  25.5
# Bulgaria                                            36.4  35.8  38.1  38.6
# Czech Republic                                      15.3  13.0  12.5  14.0
# Denmark                                             20.2  20.3  21.8  18.9
# Germany (until 1990 former territory of the FRG)    21.3  21.9  20.8  20.8
# ...

# %%
percentage_towns_and_suburbs1 = percentage_towns_and_suburbs_pulito.set_index("GEO/TIME")
percentage_towns_and_suburbs1
# Out:
#                                                     2008  2009  2010  2011  \
# GEO/TIME
# European Union (EU6-1972, EU9-1980, EU10-1985, ...   NaN   NaN   NaN  21.3
# European Union (current composition)                 NaN   NaN  20.4  21.4
# European Union (before the accession of Croatia)    20.4  20.0  20.3  21.3
# Euro area (EA11-2000, EA12-2006, EA13-2007, EA1...   NaN   NaN   NaN  21.1
# Euro area (19 countries)                            19.8  19.7  20.1  21.1
# Euro area (18 countries)                            19.8  19.7  20.1  21.1
# Belgium                                             16.8  16.8  16.4  15.4
# Bulgaria                                            47.6  54.7  53.0  54.7
# Czech Republic                                      16.9  15.4  14.3  14.9
# Denmark                                             13.0  15.2  15.9  15.9
# Germany (until 1990 former territory of the FRG)    17.3  16.1  17.1  18.0
# ...

# %% [markdown]
# # Questi grafici sono stati costruiti per visualizzare tutti i dati raccolti da EUROSTAT in tre Stati significativi ed eterogenei suddivisi per differenti gradi di urbanizzazione dal 2008 al 2016

# %%
percentage_rural_areas1.loc[["Italy", "Latvia", "Netherlands"], ["2008", "2009", "2010", "2011", "2012", "2013", "2014", "2015", "2016"]].T.plot()

# %%
percentage_cities1.loc[["Italy", "Latvia", "Netherlands"], ["2008", "2009", "2010", "2011", "2012", "2013", "2014", "2015", "2016"]].T.plot()

# %%
percentage_towns_and_suburbs1.loc[["Italy", "Latvia", "Netherlands"], ["2008", "2009", "2010", "2011", "2012", "2013", "2014", "2015", "2016"]].T.plot()

# %%
serie_dati = {"Italy": {2008: 28.8, 2011: 31.4, 2016: 31.0}, "Latvia": {2008: 39.3, 2011: 44.2, 2016: 35.0}, "Netherlands":{2008: 19.8, 2011: 6.5, 2016:12.4}}
df_serie_dati = pd.DataFrame(serie_dati)
serie_dati
# Out:
# {'Italy': {2008: 28.8, 2011: 31.4, 2016: 31.0},
#  'Latvia': {2008: 39.3, 2011: 44.2, 2016: 35.0},
#  'Netherlands': {2008: 19.8, 2011: 6.5, 2016: 12.4}}

# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# # Questi grafici sono stati costruiti per carpire le differenze di tendenza in tre Stati significativi ed eterogenei nei risultati della ricerca EUROSTAT tra il periodo precedente allo scoppio della crisi a quello immediatamente successivo

# %%
df_serie_dati.plot(kind = "line", grid = True, rot=45, figsize = (10,5))

# %%
serie_dati1 = {"Italy": {2008: 25.2, 2011: 27.1, 2016: 26.3}, "Latvia": {2008: 23.1, 2011: 39.9, 2016: 29.9}, "Netherlands":{2008: 14.2, 2011: 14.6, 2016:12.7}}
df_serie_dati1 = pd.DataFrame(serie_dati1)
df_serie_dati1.plot(kind = "line", grid = True, rot=45, figsize = (10,5))

# %%
serie_dati2 = {"Italy": {2008: 24.5, 2011: 27.8, 2016: 30.3}, "Latvia": {2008: 29.5, 2011: 35.5, 2016: 22.1}, "Netherlands":{2008: 15.1, 2011: 16.5, 2016:19.9}}
df_serie_dati2 = pd.DataFrame(serie_dati2)
df_serie_dati2.plot(kind = "line", grid = True, rot=45, figsize = (10,5))
